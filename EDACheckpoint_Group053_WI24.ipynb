# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Ethan Kim
# - Jonah Davis
# - Joseph Byrd
# - Justin He
# - Rohun Kulshrestha

# %% [markdown]
# # Research Question

# %% [markdown]
# What factors contribute to the density and migration patterns of monarch butterflies over time?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# This brief literature review will examine prior work relating to the migration patterns of Monarch butterflies (*Danaus plexippus*) and possible catalysts. Our research seeks to elucidate factors that contribute to the migration patterns and population density of Monarch butterflies over time. Studies such as Lemoine (2015) suggest that climate change is likely to alter the breeding ground distributions of eastern migratory Monarchs via range expansion of Asclepias host plants, potentially affecting Monarch distributions due to changes in host plant availability and habitat sustainability <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). Continuing on the climate front, Cohen (2023) highlighted that Monarchs born under autumn-like conditions showed lower post-metabolic rates and greater flight efficiency compared to those born under summer-like conditions <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). This observation coupled with historic climate data could aid in determining causal factors for migration pattern anomalies present in the population data. Climate aside, Flockhart et al (2015) have demonstrated that habitat loss on breeding grounds due to agricultural practices has been identified as a significant factor driving population declines in Monarch butterflies <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). Monarch butterflies utilize milkweed in cornfields throughout their breeding season, Oberhauser et al (2001) suggests that due to per-plant densities being higher in agricultural habitats than nonagricultural habitats, coupled with the prevalence of agricultural land, most Monarchs produced in the upper Midwest originated from cornfields or another agricultural land <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). The researchers suggest that agricultural practices such as weed control and insecticide use could significantly impact Monarch populations due to the loss of milkweed habitats in the areas aforementioned. While the studies by Lemoine (2015) and Flockhart et al. (2015) offer significant insights into the impact of climate change and habitat loss on Monarch populations, there is a gap in our understanding of the relationship between climate events and migration timing; we seek to bridge this gap by employing statistical techniques and machine learning. Methods to track the migration patterns and population density follow.
#
# Mehmood et al (2023) compiled a project to track Monarch butterfly migration patterns utilizing web scraping, data processing, mapping via Python, and a Google Cloud AutoML Image Classification Model<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5). With these methods the researchers aggregated Citizen Science data related to Monarch butterfly sightings and verified said sightings using machine learning. Similarly, our project will utilize Citizen Science coupled with observations from iNaturalist to refine the analysis of migration patterns. Monarch sighting and temperature data were categorized from 1997-2023 and plotted on a map of the US(link to map). Recent studies have suggested that Monarchs have experienced an alarming decline in population size due to a combination of deforestation, loss of native milkweed and nectar plants, and climate change. In a similar approach, Patel et al (2021) developed an open-source tool utilizing deep convolutional neural networks to track Monarch sightings <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6). Mahr (2024) developed a visualization project in R that visualizes the annual migration patterns of Monarch butterflies using data from the Global Biodiversity Information Facility <a name="cite_ref-7"></a>[<sup>7</sup>](#cite_note-7). This project showcases the movement patterns of Monarchs month-over-month providing a strong basis from which we may architect our code for similar migration analysis. By adapting these techniques, we aim to further our understanding of Monarch migration patterns about habitat and climate change. These studies make explicit the ability to track the migration patterns of Monarch butterflies synchronously with variables such as temperature and deforestation.
#
# Our project aims to build upon the work of the aforementioned studies, employing machine learning techniques to accurately predict Monarch migration patterns in response to climate change, milkweed density, and other confounding variables that may be uncovered throughout the course of this research.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Lemoine, N. (2015). Climate Change May Alter Breeding Ground Distributions of Eastern Migratory Monarchs (*Danaus plexippus*) via Range Expansion of Asclepias Host Plants. PLoS ONE, 10. https://doi.org/10.1371/journal.pone.0118614.
#
# 2.  <a name="cite_note-2"></a> [^](#cite_ref-2) https://adapt136.ucsc.edu/taxa/invertebrates/too-cold-for-comfort-how-climate-change-is-affecting-the-monarch-butterfly
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Flockhart, D., Pichancourt, J., Norris, D., & Martin, T. (2015). Unravelling the annual cycle in a migratory animal: breeding-season habitat loss drives population declines of monarch butterflies.. The Journal of animal ecology, 84 1, 155-65 . https://doi.org/10.1111/1365-2656.12253.
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Oberhauser, K., Prysby, M., Mattila, H., Stanley-Horn, D., Sears, M., Dively, G., Olson, E., Pleasants, J., Lam, W., & Hellmich, R. (2001). Temporal and spatial overlap between monarch larvae and corn pollen. Proceedings of the National Academy of Sciences of the United States of America, 98, 11913 - 11918. https://doi.org/10.1073/pnas.211234298.
#
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) https://devpost.com/software/a-climate-based-analysis-of-monarch-butterfly-patterns
#
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) Using Deep Learning to Count Monarch Butterflies in Dense Clusters, Shruti Patel, Amogh Kulkari, Ayan Mukhopadhyay, Karuna Gujar, Jaap de Roode bioRxiv 2021.07.23.453502; doi: https://doi.org/10.1101/2021.07.23.453502
#
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7) https://medium.com/@jakeamahr/using-rgbif-to-visualize-annual-monarch-butterfly-migrations-f34a335b77f1

# %% [markdown]
# # Hypothesis

# %% [markdown]
# H<sub>0</sub>: Historic climate and milkweed population cannot predict the migration patterns and population density of Monarch butterflies in North America.
#
# H<sub>a1</sub>: Historic climate data can predict the migration patterns and population density of Monarch butterflies in North America.
#
# H<sub>a2</sub>: Milkweed population data can predict the migration patterns and population density of Monarch butterflies in North America.
#
# Given the scope of the relevant literature and available datasets, we believe that we can produce a model that can effectively predict the migration patterns and population density of Monarch butterflies in North America. Considering that the reliable tracking of Monarch migration patterns has been demonstrated, we feel confident in predicting these patterns with the added factors of climate change and milkweed density.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1
#   - Dataset Name: iNaturalist Monarch Butterfly Observations
#   - Link to the dataset: https://www.inaturalist.org/observations?d1=03-01-2008&d2=2024-02-01&place_id=97394&taxon_id=48662&verifiable=any
#   - Number of observations: 278256
#   - Number of variables: 39
# - Dataset #2
#   - Dataset Name: iNaturalist Milkweed Observations
#   - Link to the dataset: https://www.inaturalist.org/observations?d1=03-01-2008&d2=2024-02-01&place_id=97394&taxon_id=47906&verifiable=any
#   - Number of observations: 352212
#   - Number of variables: 39
# - Dataset #3
#   - Dataset Name: Berkeley Earth Global Gridded Temperature Data: Global Monthly Land + Ocean Average Temperature with Air Temperatures at Sea Ice (Recommended; 1850 – Recent)
#   - Link to the dataset: https://berkeleyearth.org/data/
#   - Number of observations: 135302400
#   - Number of variables: 4
#
# The datasets from iNaturalist contain user-submitted observations of Monarch butterflies and milkweed plants. We queried the data to filter for observations that are only in North America from 2008-03-01 to 20204-02-01. The iNaturalist datasets contain many unnecessary variables (user_id, taxon, etc.) that we will likely drop, as we are mainly interested in the date observed, latitutude, and longitude of each observation for each species.
#
# The dataset from Berkeley Earth contains average air temperatures across a latitude-longitude grid from 1850 to the present. The only variables are time, latitude, longitude, and temperature, all of which we will keep. It should be noted that the temperature is reported in degrees Celsius as anomolies relative to the January 1951-December 1980 average. A 30-year baseline period is standard for modeling climate change <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1), and the global average air temperature during the 1951-1980 period was 14 degrees Celsius <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). Because this dataset has observations from around the globe over a large time frame, there will be many rows that are outside of North America and/or outside the date range that will be dropped.
#
# Since we are modeling whether milkweed population data and historical climate data can predict the population of Monarch butterflies, we will create and assign regions based on the latitude and longitude values and group the data by month and region.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Working Group I: The Scientific Basis. *The Intergovernmental Panel on Climate Change*. https://archive.ipcc.ch/ipccreports/tar/wg1/483.htm
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) World of Change: Global Temperatures. *NASA Earth Observatory*. https://earthobservatory.nasa.gov/world-of-change/global-temperatures#:~:text=The%20data%20reflect%20how%20much,several%20tenths%20of%20a%20degree.)

# %% [markdown]
# # Setup

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from datetime import datetime, timedelta
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans
import seaborn as sns

# %% [markdown]
# ## Inaturalist data (Monarch and Milkweed)

# %%
#monarch butterfly csv files from iNaturalist
monarch_2008_2021 = pd.read_csv('monarch_2008-2021.csv')
monarch_2021_2024 = pd.read_csv('monarch_2021-2024.csv')
monarch_df = pd.concat([monarch_2008_2021, monarch_2021_2024], ignore_index=True)

#cleaning monarch data
columns_to_keep = ['observed_on', 'latitude', 'longitude']
monarch_df = monarch_df[columns_to_keep]

# drop null rows
monarch_df = monarch_df.dropna()

# rename observed_on column to time
monarch_df.rename(columns={'observed_on': 'time'}, inplace=True)

# change 'time' values from string to datetime object
monarch_df['time'] = pd.to_datetime(monarch_df['time'])

# %%
# milkweed butterfly csv files from iNaturalist
milkweed_2008_2021 = pd.read_csv('milkweed_2008-2021.csv')
milkweed_2021_2024 = pd.read_csv('milkweed_2021-2024.csv')
milkweed_df = pd.concat([milkweed_2008_2021, milkweed_2021_2024], ignore_index=True)

#cleaning milkweed data
# drop unecessary columns
columns_to_keep = ['observed_on', 'latitude', 'longitude']
milkweed_df = milkweed_df[columns_to_keep]

# drop null rows
milkweed_df = milkweed_df.dropna()

# rename observed_on column to time
milkweed_df.rename(columns={'observed_on': 'time'}, inplace=True)

# change 'time' values from string to datetime object
milkweed_df['time'] = pd.to_datetime(milkweed_df['time'])
# Out:
# /var/folders/24/cxxsvzd91kxddwmnf88d1kqc0000gn/T/ipykernel_63699/171179954.py:3: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   milkweed_2021_2024 = pd.read_csv('milkweed_2021-2024.csv')

# %% [markdown]
# ## Temperature Data set

# %%
#Temperature dataset from _________
#open NetCDF file and access 'temperature' variable
dataset = xr.open_dataset('Land_and_Ocean_LatLong1.nc')
temperature_data = dataset['temperature']

# convert DataArray to a pandas DataFrame
temperature_df = temperature_data.to_dataframe()

# reset the index to keep coordinates as columns
temperature_df.reset_index(inplace=True)

# %%
#cleaning temperature data
# helper function to check if year is leap year
def is_leap(year):
    return (year % 4 == 0 and (year % 400 == 0 or year % 100 != 0))

# function to convert from fractional year to datetime object taking leap years into account
def convert_fractional_year(frac_year):
    if isinstance(frac_year, datetime):
        return frac_year
    year = int(frac_year)
    frac = frac_year - year
    if (year % 4):
        days_in_year = 366
    else:
        days_in_year = 365
    days_passed = int(days_in_year * frac)
    start_date = datetime(year, 1, 1)
    date = start_date + timedelta(days=days_passed)
    return date

# drop null rows
temperature_df = temperature_df.dropna()

# drop rows not in latitude-longitude range
min_lat = min(monarch_df['latitude'].min(), milkweed_df['latitude'].min())
max_lat = max(monarch_df['latitude'].max(), milkweed_df['latitude'].max())
min_long = min(monarch_df['longitude'].min(), milkweed_df['longitude'].min())
max_long = max(monarch_df['longitude'].max(), milkweed_df['longitude'].max())
temperature_df = temperature_df[(temperature_df['latitude'] >= min_lat) & (temperature_df['latitude'] <= max_lat)]
temperature_df = temperature_df[(temperature_df['longitude'] >= min_long) & (temperature_df['longitude'] <= max_long)]

# convert time from fractional year to YYYY-MM-DD format
temperature_df['time'] = temperature_df['time'].apply(convert_fractional_year)

# drop rows not in date range
start_date = min(monarch_df['time'].min(), milkweed_df['time'].min())
end_date = max(monarch_df['time'].max(), milkweed_df['time'].max())
temperature_df = temperature_df[(temperature_df['time'] >= start_date) & (temperature_df['time'] <= end_date)]

# change latitude and longitude value types to float64
temperature_df[['latitude', 'longitude']] = temperature_df[['latitude', 'longitude']].astype(float)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Temperature Data
# ...stuff about data source...

# %%
fig, axes = plt.subplots(2,1)

sns.lineplot(data = temperature_df, x = 'time', y = 'temperature',
            ax=axes[0])
axes[0].set_title('Temperature 2008-2024')

sns.lineplot(data = temperature_df[temperature_df['time'].dt.year == 2023], x = 'time', y ='temperature', ax=axes[1])
axes[1].set_title('Temperature 2023')

plt.tight_layout()

# %%
#narrow down temperature observations to a specific month 
sub_temp = temperature_df[temperature_df['time'].dt.month == 6]

# Create a pivot table to reshape the data for the heatmap
pivot_df = sub_temp.pivot_table(index='latitude', columns='longitude', values='temperature')


# Plot the heatmap
plt.figure(figsize=(10, 6))
temp_map = sns.heatmap(pivot_df, cmap='coolwarm', annot=False, fmt=".1f")

#inverts the y axis 
temp_map.invert_yaxis()

temp_map.set_title('Temperature Average for June (years 2008-2024)')
plt.show()

# %% [markdown]
# ### Exploring Monarch and Milkweed data

# %%
#creates a species column to merge together monarch and milkweed observations
sub_monarch_df = monarch_df
sub_monarch_df['species'] = 'monarch'

sub_milkweed_df = milkweed_df
sub_milkweed_df['species'] = 'milkweed'

#merge observations together to a species df
species_df = pd.concat([monarch_df, milkweed_df], ignore_index=True)
species_df
# Out:
#              time   latitude   longitude  region   species
# 0      2009-03-01  26.078794  -80.278366      16   monarch
# 1      2009-09-13  26.080471  -80.277916      16   monarch
# 2      2009-06-08  35.557690 -121.081589      38   monarch
# 3      2010-08-28  40.241203  -76.056328      24   monarch
# 4      2009-06-09  38.566663 -122.684812      38   monarch
# ...           ...        ...         ...     ...       ...
# 594301 2024-01-02  41.700092  -81.250438       0  milkweed
# 594302 2022-09-25  45.383540  -74.195939      42  milkweed
# 594303 2023-06-21  38.875559  -96.950733      45  milkweed
# 594304 2023-05-24  35.845706  -78.795036      24  milkweed
# 594305 2021-07-26  43.872866  -79.236480      25  milkweed
#
# [594306 rows x 5 columns]

# %%
histplot = sns.histplot(data=species_df, x = 'time', hue='species')

histplot.set_title('Inaturalist Observations of Monarchs and Milkweeds Over Time')
histplot.set_xlabel('Year')
histplot.set_ylabel('Number of Observations ')
plt.show()

# %% [markdown]
# There is an interesting cyclic pattern to these data, and we can see that the number of observations across the board rises exponentially.
#
# We can assume there would be some variation in observations because of seasonality. But it seems that there is another variable affecting the plot.
#
# From https://www.inaturalist.org/blog/82561-150-000-000-observations-on-inaturalist we can see that the number of inaturalist users has risen in a similar way, and also the number of inaturalist observations as a whole behaves in a seasonal way. We will keep this in mind for our analysis as a potential bias to the data.

# %%
sub_species_df = species_df[species_df['time'].dt.year == 2023]
sub_species_df
sns.histplot(data=sub_species_df, x = 'time', hue='species', bins=12, kde=True)
# Out:
# <Axes: xlabel='time', ylabel='Count'>

# %% [markdown]
# Narrowing down to just one year (2023), We can see that milkweed observations preceed monarch observations.
#
# Milkweeds are decideous, and do not have foliage during late fall and winter. They do bloom from June to August which can explain the spike in observations over that period (Source: https://www.xerces.org/milkweed-faq#:~:text=In%20contrast%2C%20the%20majority%20of,during%20late%20fall%20and%20winter.)
#
# As far as Monarchs go, their abundance is a bit more complicated. However it does make sense to see more observations during the summer months as monarchs migrate from south America (and inland from the coast of California) (source: https://www.xerces.org/blog/5-monarch-migration-facts)
#
# We will need to use spatial visualizations to see if our data shares this expected pattern.

# %%
fig, axes = plt.subplots(2,1, figsize = (12,12))

map1 = sns.scatterplot(data=species_df[species_df['species'] == 'monarch'],
                y = 'latitude', x = 'longitude', hue ='species',
                s = 15, alpha = .5, ax=axes[0])
map1.set_title('Inaturalist Monarch Observations (Summed 2009-2024)')



#create a month column for 
species_df['month'] = species_df['time'].dt.month

colors = sns.diverging_palette(10, 50, as_cmap=True)

map2 = sns.scatterplot(data=species_df[species_df['species'] == 'monarch'],
                y = 'latitude', x = 'longitude', hue ='month', legend='full',
                s = 15, palette=colors, ax=axes[1])
map2.set_title('Inaturalist Monarch Observations by Month (Summed 2009-2024)')

plt.show()

# %% [markdown]
# The top figure shows us that monarch observations are not equally distirbuted across North America, and there is a considerable gap in the data towards the west end of the U.S. This is more of a gap than would be expected from monarch migrations as summed through 2009-2024. This bias could be from the distirbution of Inaturalist users being in more populated areas.
#
# The bottom figure replots the same plots but with a gradient representing the month the observation was taken. We can see that there seems to be more observations in the south/coast of California in the winter months, and less in the summer. This is great, as this follows the pattern we expect of migration! (source: https://www.xerces.org/blog/5-monarch-migration-facts)
#
# It may be helpful to few the longitude/latitude individually to spot/confirm these patterns.

# %%
fig, axes = plt.subplots(1,2, figsize = (12,8))

#narrow monarch dataframe to just observations in 2023
monarch_df_2023 = monarch_df[monarch_df['time'].dt.year == 2023]


sns.histplot(data= monarch_df_2023,
                y = 'latitude', x='time', ax=axes[0])
#get the mean latitude for each date
mean_latitudes = monarch_df_2023.groupby('time')['latitude'].mean()
#plot the mean onto left figure
sns.lineplot(data=mean_latitudes, 
             x=mean_latitudes.index, y=mean_latitudes.values, ax=axes[0], color ='g', alpha=.5)


sns.histplot(data= monarch_df_2023,
                y = 'longitude', x='time', ax=axes[1])
#get the mean latitude for each date
mean_longitudes = monarch_df_2023.groupby('time')['longitude'].mean()
#plot the mean onto right figure 
sns.lineplot(data=mean_longitudes, 
             x=mean_longitudes.index, y=mean_longitudes.values,ax=axes[1], color ='g', alpha=.5)
# Out:
# <Axes: xlabel='time', ylabel='longitude'>

# %% [markdown]
# The left and right figures are latitude and longitude plotted seperated across time. The blue represents the observations and the green is a trendline of the mean latitude/longitude for each date. We can see there is a general pattern towards higher latitudes and longtitudes during the summer and lower in the winter. But we will need to perform statistical tests to see if this is a true pattern.

# %% [markdown]
# ## Merging data

# %% [markdown]
# To create the final dataframe, we wanted to create a region column. Rather than make the region based off of state/province, we decided to choose the region with K-means clustering (note: the number of clusters that will be used is undecided and may be adjusted in the future). We then grouped the temperature, milkweed, and monarch data by month and region. We also created a new column which is the actual temperature in degrees Celsius, rather than the temperature measured as anomolies relative to the baseline period.

# %%
# combine all latitude and longitude data from dataframes
coordinates = np.vstack((
    temperature_df[['latitude', 'longitude']].values,
    milkweed_df[['latitude', 'longitude']].values,
    monarch_df[['latitude', 'longitude']].values))

# perform K-means clustering
num_clusters = 50  # to be adjusted
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(coordinates)

# assign clusters as regions back to each dataframe
temperature_df['region'] = kmeans.predict(temperature_df[['latitude', 'longitude']].astype(float))
milkweed_df['region'] = kmeans.predict(milkweed_df[['latitude', 'longitude']])
monarch_df['region'] = kmeans.predict(monarch_df[['latitude', 'longitude']])
# Out:
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(

# %%
# aggregate temperature data on a monthly basis by region
temperature_monthly_avg = temperature_df.groupby(['region', pd.Grouper(key='time', freq='M')]).temperature.mean().reset_index()

# aggregate milkweed presence on a monthly basis by region
milkweed_presence = milkweed_df.assign(presence=1).groupby(['region', pd.Grouper(key='time', freq='M')]).presence.max().reset_index()

# aggregate monarch counts on a monthly basis by region
monarch_monthly_counts = monarch_df.groupby(['region', pd.Grouper(key='time', freq='M')]).size().reset_index(name='monarch_count')

# merge aggregated temperature and milkweed presence on region and time
features_df = pd.merge(temperature_monthly_avg, milkweed_presence, on=['region', 'time'], how='outer').fillna({'presence': 0})

# merge the above with monarch counts to include monarch population data
final_df = pd.merge(features_df, monarch_monthly_counts, on=['region', 'time'], how='left').fillna({'monarch_count': 0})

# drop null rows
final_df = final_df.dropna()

# create new column called actual_temperature which is the temperature as an anomoly plus the baseline average
baseline_temperature = 14
final_df['actual_temperature'] = final_df['temperature'] + baseline_temperature

# %%
final_df.head()
# Out:
#    region       time  temperature  presence  monarch_count  actual_temperature
# 0       0 2008-03-31    -0.538057       0.0            0.0           13.461944
# 1       0 2008-04-30     1.601274       0.0            0.0           15.601274
# 2       0 2008-05-31    -1.203396       0.0            0.0           12.796604
# 3       0 2008-06-30     1.244324       1.0            4.0           15.244324
# 4       0 2008-07-31     0.342339       1.0            2.0           14.342340

# %%
sns.scatterplot(final_df, x = 'actual_temperature', y = 'monarch_count')
# Out:
# <Axes: xlabel='actual_temperature', ylabel='monarch_count'>

# %% [markdown]
# ### K-means clustering
#
# Trying out the Elbox method for determining cluster size

# %%
inertias = []
k_values = range(1, 21)  # adjust the range based on your needs

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42).fit(monarch_df[['latitude', 'longitude']])
    inertias.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertias, 'bo-')
plt.xlabel('Number of Clusters, k')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/josephbyrd/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# - Thoughtful discussion of ethical concerns included
# - Ethical concerns consider the whole data science process (question asked, data collected, data being used, the bias in data, analysis, post-analysis, etc.)
# - How your group handled bias/ethical concerns clearly described
#
# Acknowledge and address any ethics & privacy related issues of your question(s), proposed dataset(s), and/or analyses. Use the information provided in lecture to guide your group discussion and thinking. If you need further guidance, check out [Deon's Ethics Checklist](http://deon.drivendata.org/#data-science-ethics-checklist). In particular:
#
# - Are there any biases/privacy/terms of use issues with the data you propsed?
# - Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis? (For example, does your data exclude particular populations, or is it likely to reflect particular human biases in a way that could be a problem?)
# - How will you set out to detect these specific biases before, during, and after/when communicating your analysis?
# - Are there any other issues related to your topic area, data, and/or analyses that are potentially problematic in terms of data privacy and equitable impact?
# - How will you handle issues you identified?

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# * *Team Expectation 1*
# * *Team Expectation 2*
# * *Team Expecation 3*
# * ...

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26  |  10 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/1  | 10 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/14  | 6 PM  | Import & Wrangle Data (Ant Man); EDA (Hulk) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/23  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Iron Man; Thor) | Discuss/edit Analysis; Complete project check-in |
# | 3/13  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Wasp)| Discuss/edit full project |
# | 3/20  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
